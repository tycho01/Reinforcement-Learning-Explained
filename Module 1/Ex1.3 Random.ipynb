# %% [markdown]
# # DAT257x: Reinforcement Learning Explained
#
# ## Lab 1: Environments and Agents
#
# ### Exercise 3: Random Agent

# %% [markdown]
# Now that you have examine the SimpleRoomsEnv and CliffWalkingEnv environments in the Environments.py file, let's play around with an agent in those environments.

# %%
import sys
# !{sys.executable} -m pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading https://files.pythonhosted.org/packages/49/b8/89dbd27f2fb171ce753bb56220d4d4f6dbc5fe32b95d8edc4415782ef07f/matplotlib-2.2.2-cp36-cp36m-manylinux1_x86_64.whl (12.6MB)
#     100% |████████████████████████████████| 12.6MB 124kB/s ta 0:00:011
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading https://files.pythonhosted.org/packages/f7/d2/e07d3ebb2bd7af696440ce7e754c59dd546ffe1bbe732c8ab68b9c834e61/cycler-0.10.0-py2.py3-none-any.whl
# Collecting pytz (from matplotlib)
#   Downloading https://files.pythonhosted.org/packages/dc/83/15f7833b70d3e067ca91467ca245bae0f6fe56ddc7451aa0dc5606b120f2/pytz-2018.4-py2.py3-none-any.whl (510kB)
#     100% |████████████████████████████████| 512kB 1.4MB/s ta 0:00:01
# Collecting python-dateutil>=2.1 (from matplotlib)
#   Downloading https://files.pythonhosted.org/packages/0c/57/19f3a65bcf6d5be570ee8c35a5398496e10a0ddcbc95393b2d17f86aaaf8/python_dateutil-2.7.2-py2.py3-none-any.whl (212kB)
#     100% |████████████████████████████████| 215kB 2.1MB/s ta 0:00:01
# Collecting pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 (from matplotlib)
#   Downloading https://files.pythonhosted.org/packages/6a/8a/718fd7d3458f9fab8e67186b00abdd345b639976bc7fb3ae722e1b026a50/pyparsing-2.2.0-py2.py3-none-any.whl (56kB)
#     100% |████████████████████████████████| 61kB 2.5MB/s ta 0:00:01
# Collecting six>=1.10 (from matplotlib)
#   Downloading https://files.pythonhosted.org/packages/67/4b/141a581104b1f6397bfa78ac9d43d8ad29a7ca43ea90a2d863fe3056e86a/six-1.11.0-py2.py3-none-any.whl
# Collecting numpy>=1.7.1 (from matplotlib)
#   Downloading https://files.pythonhosted.org/packages/6e/dc/92c0f670e7b986829fc92c4c0208edb9d72908149da38ecda50d816ea057/numpy-1.14.2-cp36-cp36m-manylinux1_x86_64.whl (12.2MB)
#     100% |████████████████████████████████| 12.2MB 126kB/s ta 0:00:011
# Collecting kiwisolver>=1.0.1 (from matplotlib)
#   Downloading https://files.pythonhosted.org/packages/69/a7/88719d132b18300b4369fbffa741841cfd36d1e637e1990f27929945b538/kiwisolver-1.0.1-cp36-cp36m-manylinux1_x86_64.whl (949kB)
#     100% |████████████████████████████████| 952kB 740kB/s ta 0:00:01
# Collecting setuptools (from kiwisolver>=1.0.1->matplotlib)
#   Downloading https://files.pythonhosted.org/packages/20/d7/04a0b689d3035143e2ff288f4b9ee4bf6ed80585cc121c90bfd85a1a8c2e/setuptools-39.0.1-py2.py3-none-any.whl (569kB)
#     100% |████████████████████████████████| 573kB 1.3MB/s ta 0:00:01
# Installing collected packages: six, cycler, pytz, python-dateutil, pyparsing, numpy, setuptools, kiwisolver, matplotlib
# Successfully installed cycler-0.10.0 kiwisolver-1.0.1 matplotlib-2.2.2 numpy-1.14.2 pyparsing-2.2.0 python-dateutil-2.7.2 pytz-2018.4 setuptools-39.0.1 six-1.11.0

# %%
import numpy as np
import sys
import os
sys.path.append(os.getcwd())
sys.path.append(os.getcwd() + "/../")
from lib.envs.simple_rooms import SimpleRoomsEnv
from lib.envs.cliff_walking import CliffWalkingEnv
from lib.simulation import Experiment

# %% [markdown]
# Below is the agent interface. At the minimum, an agent will have an act() function that takes an observation, and return an action.

# %%
class Agent(object):

    def __init__(self, actions):
        self.actions = actions
        self.num_actions = len(actions)

    def act(self, obs):
        raise NotImplementedError

# %% [markdown]
# We've given you the implementation of a random agent. It's act() function will just return a random action within the valid action space.

# %%
class RandomAgent(Agent):
    
    def __init__(self, actions):
        super(RandomAgent, self).__init__(actions)
    
    def act(self, obs):
        return np.random.randint(0, self.num_actions)

# %% [markdown]
# Now let's run the experiment. We'll start with the SimpleRoomsEnv environment, with just 5 episodes.

# %%
interactive = True
# %matplotlib nbagg

# %%
max_number_of_episodes = 5
env = SimpleRoomsEnv()
agent = RandomAgent(range(env.action_space.n))
experiment = Experiment(env, agent)
experiment.run_agent(max_number_of_episodes, interactive)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# Let's do one with the CliffWalkingEnv environment. This time with 10 episodes.

# %%
max_number_of_episodes = 10
env = CliffWalkingEnv()
agent = RandomAgent(range(env.action_space.n))
experiment = Experiment(env, agent)
experiment.run_agent(max_number_of_episodes, interactive)
# Out:
# <div id='24a2d5da-f135-4d45-9152-a4f9ef929c15'></div>
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-6-0d3ffd6c890d> in <module>()
#       3 agent = RandomAgent(range(env.action_space.n))
#       4 experiment = Experiment(env, agent)
# ----> 5 experiment.run_agent(max_number_of_episodes, interactive)
#
# ~/Desktop/Reinforcement-Learning-Explained/Module 1/../lib/simulation.py in run_agent(self, max_number_of_episodes, interactive, display_frequency)
#     141                 # if interactive display, show update for each step
#     142                 if interactive:
# --> 143                     self.update_display_step()
#     144
#     145             self.episode_length = np.append(self.episode_length,t) # keep episode length - for display
#
# ~/Desktop/Reinforcement-Learning-Explained/Module 1/../lib/simulation.py in update_display_step(self)
#      54     def update_display_step(self):
#      55         if not hasattr(self, 'imgplot'):
# ---> 56             self.imgplot = self.ax.imshow(self.env.render(mode='rgb_array'), interpolation='none', cmap='viridis')
#      57         else:
#      58             self.imgplot.set_data(self.env.render(mode='rgb_array'))
#
# ~/.local/lib/python3.6/site-packages/gym/core.py in render(self, mode)
#     109                     super(MyEnv, self).render(mode=mode) # just raise an exception
#     110         """
# --> 111         raise NotImplementedError
#     112
#     113     def close(self):
#
# NotImplementedError:

# %% [markdown]
# Let's set interactive to False, and run the experiments again. This time with 100 episodes each.

# %%
interactive = False
# %matplotlib inline

# %%
max_number_of_episodes = 100
env = SimpleRoomsEnv()
agent = RandomAgent(range(env.action_space.n))
experiment = Experiment(env, agent)
experiment.run_agent(max_number_of_episodes, interactive)

# %%
max_number_of_episodes = 100
env = CliffWalkingEnv()
agent = RandomAgent(range(env.action_space.n))
experiment = Experiment(env, agent)
experiment.run_agent(max_number_of_episodes, interactive)
